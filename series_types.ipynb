# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# # Yearly (Cycle)

# %% [markdown]
# The Canadian lynx data set used in time series modelling is the annual record of the number of the Canadian lynx "trapped" in the Mackenzie River district of the North-West Canada for the period 1821–1934.

# %%
ts_lynx = pd.Series.from_csv("data/canadian_lynx.csv")
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/series.py:2890: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)

# %%
ts_lynx.head()
# Out:
# 1821-01-01     269
# 1822-01-01     321
# 1823-01-01     585
# 1824-01-01     871
# 1825-01-01    1475
# dtype: int64

# %%
ts_lynx[:50].plot(figsize=(15, 5))

# %%
ts_lynx_ma = ts_lynx.rolling(3).mean()
ts_lynx_ma.plot(figsize=(15, 5))

# %%
result = seasonal_decompose(ts_lynx)
result.plot()

# %% [markdown]
# # Weakly (Periodical)

# %% [markdown]
# Weekly data on US finished motor gasoline products supplied (in thousands of barrels per day) from February 1991 to May 2005.

# %%
ts_gasoline = pd.Series.from_csv("data/gasoline.csv")
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/series.py:2890: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)

# %%
print(len(ts_gasoline))
# Out:
# 745

# %%
ts_gasoline.plot(figsize=(15, 5))

# %%
ts_gasoline_ma = ts_gasoline.rolling(5).mean()
ts_gasoline_ma.plot(figsize=(15, 5))

# %%
result = seasonal_decompose(ts_gasoline)
result.plot()

# %%
print("Input series:")
print(np.ptp(ts_gasoline))
print(np.max(ts_gasoline))
print(np.min(ts_gasoline))
print("Trend component:")
print(np.ptp(result.trend))
print(np.max(result.trend))
print(np.min(result.trend))
result.trend.plot(figsize=(15,5))
# Out:
# Input series:
# 3347.0
# 9668.0
# 6321.0
# Trend component:
# 1931.75
# 9116.846153846154
# 7185.096153846154

# %% [markdown]
# # Daily

# %% [markdown]
# Daily minimum temperatures in Melbourne, Australia, 1981-1990

# %%
ts_temprature = pd.Series.from_csv("data/temperatures.csv")
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/series.py:2890: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)

# %%
ts_temprature.plot(figsize=(15, 5))

# %%
ts_temprature_ma = ts_temprature.rolling(20).mean()
ts_temprature_ma.plot(figsize=(15, 5))
